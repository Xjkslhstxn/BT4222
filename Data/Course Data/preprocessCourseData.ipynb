# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/Users/auroraxu/Downloads/job_descriptions.csv')

# %%
print(df.shape)
# Out:
# (1615940, 23)

# %%
1615940/89184
# Out:
# 18.14159490491568

# %%
print(df.head())
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
# 4             Chile  -35.6751   -71.5429     Intern         53944  ...
#
#                  Contact                     Job Title  \
# ...

# %%
print(df['Job Title'].value_counts())
# Out:
# UX/UI Designer                  48551
# Digital Marketing Specialist    27975
# Software Engineer               27630
# Network Engineer                24393
# Software Tester                 20945
#                                 ...
# Personal Assistant               3441
# QA Engineer                      3439
# Procurement Coordinator          3424
# Key Account Manager              3411
# Inventory Analyst                3342
# Name: Job Title, Length: 147, dtype: int64

# %%
Udemy_df = pd.read_excel('Udemy 6786.xlsx')
CodeAcademy_df = pd.read_excel('CodeAcademy.xlsx')
Pluralsight_df = pd.read_excel('Pluralsight.xlsx')

# %%
import pandas as pd

# Apply the regular expression pattern
pattern = r'(?P<course_name>.+?)' \
          r'Rating: (?P<rating>\d\.\d) out of (?P<reviews>\d+) reviews' \
          r'(?P<duration>\d+\.?\d* total hours)?' \
          r'(?P<lectures>\d+ lectures)?' \
          r'(?P<level>Beginner|Intermediate|Expert|All Levels)?' \
          r'(Current price: €(?P<current_price>\d+\.\d+))?' \
          r'(Original price: €(?P<original_price>\d+\.\d+))?'

          
df_extracted = Udemy_df['Title'].str.extract(pattern)

print(df_extracted.head(20))
# Out:
#                                           course_name rating  reviews  \
# 0   Full Practice Exam | Learn Cloud Computing | P...    4.7  5214188
# 1   Full Practice Exam included + explanations | L...    4.7  5193568
# 2   Become an ethical hacker that can hack like bl...    4.6  5121803
# 3   Learn the fundamentals of Azure, and get certi...    4.6  5100175
# 4   Full Practice Exam with Explanations included!...    4.7   595029
# 5   Learn Kubernetes in simple, easy and fun way w...    4.6   581332
# 6   Everything you need to pass A+ Certification C...    4.7   575033
# 7   CompTIA Security+ (SY0-701) Bootcamp - Your pr...    4.7   570586
# 8   Prepare for the Certified Kubernetes Administr...    4.7   566002
# 9   The top rated CCNA course online with comprehe...    4.8   563529
# 10          Beginning your journey on Microsoft Azure    4.6   557372
# 11  Learn Docker with Hands On Coding Exercises. F...    4.6   552699
# ...

# %%
CodeAcademy_df.head(5)
# Out:
#                                      Course Name  \
# 0         Defending Against AI-Generated Attacks
# 1                       Intro to AI Transformers
# 2                            Intro to Midjourney
# 3  Optimizing Code with Generative AI Case Study
# 4           Intro to PyTorch and Neural Networks
#
#                                      Course Name Url  \
# 0  https://www.codecademy.com/learn/defending-aga...
# 1  https://www.codecademy.com/learn/intro-to-ai-t...
# 2  https://www.codecademy.com/learn/intro-to-midj...
# 3  https://www.codecademy.com/learn/optimizing-co...
# 4  https://www.codecademy.com/learn/intro-to-py-t...
#
#                                   Course Description              Level  \
# 0  Dive into the dangerous world of AI phishing a...                NaN
# 1  Learn about what transformers are (the T of GP...       Intermediate
# 2  Dive into the world of generative image-based-...  Beginner Friendly
# ...

# %%
Pluralsight_df.head(5)
# Out:
#                                          Course Name  \
# 0         Windows PowerShell and Regular Expressions
# 1        Ethernet Operation and Switch Configuration
# 2  Cisco Enterprise Networks: Basic Networking an...
# 3            Ethical Hacking: Vulnerability Analysis
# 4  Performing Malware Analysis on Malicious Docum...
#
#                                      Course Name Url Duration          Level  \
# 0  https://www.pluralsight.com/courses/powershell...   2h 13m  Intermediate
# 1  https://www.pluralsight.com/courses/ethernet-o...    3h 4m  Intermediate
# 2  https://www.pluralsight.com/courses/cisco-ente...   1h 45m  Intermediate
# 3  https://www.pluralsight.com/courses/vulnerabil...   1h 25m  Intermediate
# 4  https://www.pluralsight.com/courses/malware-an...   2h 59m  Intermediate
#
#    Reviews            Author
# 0       28     by Jeff Hicks
# 1       56  by Ross Bagurdes
# 2      103      by Ben Piper
# 3       61  by Dale Meredith
# 4       65    by Tyler Hudak
